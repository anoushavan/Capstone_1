# %%
import pandas as pd
import numpy as np
from datetime import datetime

# %%
data = pd.read_csv('DOB_Job_Application_Filings.csv')
# Out:
# /Users/anushavan/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (5,6,13,14,21,38,59,60,68,78,79) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data.shape
# Out:
# (1672861, 96)

# %%
data = (data.drop(
    ['House #','Street Name','Lot','Bin #',
     'GIS_LATITUDE','GIS_LONGITUDE','GIS_COUNCIL_DISTRICT',
    'GIS_CENSUS_TRACT','GIS_BIN'],axis=1))

# %%
columns = data.columns.values.tolist()

# %%
columns_to_keep = ['Borough', 
 'Job Type',
 'Job Status',
 'Job Status Descrp',
 'Latest Action Date',
 'Building Type', 'City Owned',
 'Little e',
 'PC Filed',
 'eFiling Filed', 'Pre- Filing Date',
 'Paid',
 'Fully Paid',
 'Assigned',
 'Approved',
 'Fully Permitted',
 'Initial Cost',
 'Total Est. Fee',
 'Fee Status',
 'Existing Zoning Sqft',
 'Proposed Zoning Sqft',
 'Horizontal Enlrgmt',
 'Vertical Enlrgmt',
 'Enlargement SQ Footage',
 'Street Frontage',
 'ExistingNo. of Stories',
 'Proposed No. of Stories',
 'Existing Height',
 'Proposed Height',
 'Existing Dwelling Units',
 'Proposed Dwelling Units',
 'Existing Occupancy',
 'Proposed Occupancy',
 'Site Fill',
 'Zoning Dist1',
 'Zoning Dist2',
 'Zoning Dist3',
 'Special District 1',
 'Special District 2',
 'Owner Type',
 'Non-Profit',
 'DOBRunDate',
 'JOB_S1_NO',
 'TOTAL_CONSTRUCTION_FLOOR_AREA',
 'WITHDRAWAL_FLAG',
 'SIGNOFF_DATE',
 'SPECIAL_ACTION_STATUS',
 'SPECIAL_ACTION_DATE',
 'BUILDING_CLASS',
 'JOB_NO_GOOD_COUNT',]

# %%
dobdata = data[columns_to_keep]

# %%
dobdata.shape
# Out:
# (1672861, 50)

# %%
dobdata.head()
# Out:
#      Borough Job Type Job Status            Job Status Descrp  \
# 0     QUEENS       A3          X                   SIGNED OFF
# 1     QUEENS       A2          X                   SIGNED OFF
# 2  MANHATTAN       A2          Q  PERMIT ISSUED - PARTIAL JOB
# 3   BROOKLYN       A2          X                   SIGNED OFF
# 4     QUEENS       NB          P         PLAN EXAM - APPROVED
#
#        Latest Action Date Building Type City Owned Little e PC Filed  \
# 0  08/02/2011 12:00:00 AM        OTHERS        NaN        N      NaN
# 1  10/31/2011 12:00:00 AM  1-2-3 FAMILY        NaN        N      NaN
# 2  05/23/2019 12:00:00 AM  1-2-3 FAMILY        NaN        Y      NaN
# 3  03/18/2019 12:00:00 AM  1-2-3 FAMILY        NaN        N      NaN
# 4  04/09/2019 12:00:00 AM  1-2-3 FAMILY        NaN        N      NaN
#
#   eFiling Filed        ...         Non-Profit              DOBRunDate  \
# 0           NaN        ...                  N  03/13/2019 12:00:00 AM
# ...

# %%
dobdata.columns.values
# Out:
# array(['Borough', 'Job Type', 'Job Status', 'Job Status Descrp',
#        'Latest Action Date', 'Building Type', 'City Owned', 'Little e',
#        'PC Filed', 'eFiling Filed', 'Pre- Filing Date', 'Paid',
#        'Fully Paid', 'Assigned', 'Approved', 'Fully Permitted',
#        'Initial Cost', 'Total Est. Fee', 'Fee Status',
#        'Existing Zoning Sqft', 'Proposed Zoning Sqft',
#        'Horizontal Enlrgmt', 'Vertical Enlrgmt', 'Enlargement SQ Footage',
#        'Street Frontage', 'ExistingNo. of Stories',
#        'Proposed No. of Stories', 'Existing Height', 'Proposed Height',
#        'Existing Dwelling Units', 'Proposed Dwelling Units',
#        'Existing Occupancy', 'Proposed Occupancy', 'Site Fill',
#        'Zoning Dist1', 'Zoning Dist2', 'Zoning Dist3',
#        'Special District 1', 'Special District 2', 'Owner Type',
#        'Non-Profit', 'DOBRunDate', 'JOB_S1_NO',
#        'TOTAL_CONSTRUCTION_FLOOR_AREA', 'WITHDRAWAL_FLAG', 'SIGNOFF_DATE',
# ...

# %%
from datetime import datetime
from collections import defaultdict
from operator import itemgetter

# %%
# create a defaultdict named date_issued to store the values of the number of permits issued
# on each date
date_issued = defaultdict(int)

# create a series of dates when the permit was approved
dates = dobdata.Approved

# remove all nan values
dates = dates.dropna()

# iterate over the dates series, create a datetime object and add it to the defaultict
for day in dates.values:
    try:
#         day = datetime.strptime(str(day),"%m/%d/%Y")
        date_issued[day] += 1
    except: 'ValueError'        

sorted(date_issued.items(), key=itemgetter(1),reverse = True)
# Out:
# [('06/26/2008', 663),
#  ('06/25/2008', 529),
#  ('05/21/2015', 500),
#  ('11/10/2005', 476),
#  ('12/03/2015', 474),
#  ('08/03/2016', 446),
#  ('10/11/2017', 444),
#  ('09/30/2016', 442),
#  ('07/08/2015', 441),
#  ('05/10/2017', 439),
#  ('09/29/2016', 438),
#  ('12/30/2014', 436),
#  ('06/12/2015', 433),
#  ('08/11/2016', 430),
#  ('06/01/2015', 428),
#  ('05/19/2015', 426),
#  ('06/11/2015', 426),
#  ('09/20/2017', 425),
#  ('08/14/2007', 425),
#  ('06/27/2016', 424),
#  ('05/17/2017', 421),
#  ('09/27/2016', 420),
#  ('12/14/2016', 418),
#  ('11/10/2016', 418),
#  ('05/12/2015', 418),
#  ('05/20/2015', 418),
#  ('06/29/2017', 417),
#  ('02/15/2008', 416),
#  ('05/29/2014', 415),
#  ('04/20/2005', 415),
#  ('06/16/2015', 415),
#  ('11/12/2014', 415),
#  ('06/16/2017', 414),
#  ('06/15/2017', 414),
#  ('09/09/2015', 413),
#  ('06/05/2008', 413),
#  ('07/13/2016', 412),
#  ('09/07/2017', 412),
#  ('09/01/2016', 412),
#  ('11/03/2016', 412),
#  ('10/05/2017', 410),
# ...

# %%
exper = date_issued
